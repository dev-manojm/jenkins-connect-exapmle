# %%
#!pip install jenkins
# use the above command if you face the issue of module not found in jupyter notebook even after install it fromm cmd.
import jenkins

# %%
server = jenkins.Jenkins('http://localhost:8080', username='username', password='password or api token')

# %%
user = server.get_whoami()
version = server.get_version()
print('Hello %s from Jenkins %s' % (user['fullName'], version))
# Out:
# Hello Manoj More from Jenkins 2.245

# %%
print (server.jobs_count())
# Out:
# 0

# %%
server.create_job('empty', jenkins.EMPTY_CONFIG_XML)
jobs = server.get_jobs()
print (jobs)
# Out:
# [{'_class': 'hudson.model.FreeStyleProject', 'name': 'empty', 'url': 'http://localhost:8080/job/empty/', 'color': 'notbuilt', 'fullname': 'empty'}]

# %%
my_job = server.get_job_config('empty')

# %%
print(my_job)
# Out:
# <?xml version="1.0" encoding="UTF-8"?><project>
#   <keepDependencies>false</keepDependencies>
#   <properties/>
#   <scm class="jenkins.scm.NullSCM"/>
#   <canRoam>true</canRoam>
#   <disabled>false</disabled>
#   <blockBuildWhenUpstreamBuilding>false</blockBuildWhenUpstreamBuilding>
#   <triggers class="vector"/>
#   <concurrentBuild>false</concurrentBuild>
#   <builders/>
#   <publishers/>
#   <buildWrappers/>
# </project>

# %%
server.build_job('empty')
# Out:
# 1

# %%
server.disable_job('empty')

# %%
server.copy_job('empty', 'empty_copy')

# %%
server.enable_job('empty_copy')

# %%
server.reconfig_job('empty_copy', jenkins.RECONFIG_XML)

# %%
server.delete_job('empty')
server.delete_job('empty_copy')

# %%
last_build_number = server.get_job_info('api-test')['lastCompletedBuild']['number']

# %%
build_info = server.get_build_info('api-test', last_build_number)

# %%
print(build_info)
# Out:
# {'_class': 'hudson.model.FreeStyleBuild', 'actions': [{'_class': 'hudson.model.CauseAction', 'causes': [{'_class': 'hudson.model.Cause$UserIdCause', 'shortDescription': 'Started by user Manoj More', 'userId': 'manoj_more', 'userName': 'Manoj More'}]}, {}, {}], 'artifacts': [], 'building': False, 'description': None, 'displayName': '#1', 'duration': 1269, 'estimatedDuration': 1269, 'executor': None, 'fullDisplayName': 'api-test #1', 'id': '1', 'keepLog': False, 'number': 1, 'queueId': 4, 'result': 'SUCCESS', 'timestamp': 1595429207950, 'url': 'http://localhost:8080/job/api-test/1/', 'builtOn': '', 'changeSet': {'_class': 'hudson.scm.EmptyChangeLogSet', 'items': [], 'kind': None}, 'culprits': []}

# %%
jobs = server.get_jobs(view_name='api-test')
print (jobs)
# Out:
# [{'_class': 'hudson.model.FreeStyleProject', 'name': 'api-test', 'url': 'http://localhost:8080/job/api-test/', 'color': 'blue', 'fullname': 'api-test'}]

# %%
server.create_view('EMPTY', jenkins.EMPTY_VIEW_CONFIG_XML)

# %%
view_config = server.get_view_config('EMPTY')
print(view_config)
# Out:
# <?xml version="1.1" encoding="UTF-8"?>
# <hudson.model.ListView>
#   <name>EMPTY</name>
#   <filterExecutors>false</filterExecutors>
#   <filterQueue>false</filterQueue>
#   <properties class="hudson.model.View$PropertyList"/>
#   <jobNames>
#     <comparator class="hudson.util.CaseInsensitiveComparator"/>
#   </jobNames>
#   <jobFilters/>
#   <columns>
#     <hudson.views.StatusColumn/>
#     <hudson.views.WeatherColumn/>
#     <hudson.views.JobColumn/>
#     <hudson.views.LastSuccessColumn/>
#     <hudson.views.LastFailureColumn/>
#     <hudson.views.LastDurationColumn/>
#     <hudson.views.BuildButtonColumn/>
#   </columns>
#   <recurse>false</recurse>
# </hudson.model.ListView>

# %%
views = server.get_views()
print(views)
# Out:
# [{'_class': 'hudson.model.ListView', 'name': 'EMPTY', 'url': 'http://localhost:8080/view/EMPTY/'}, {'_class': 'hudson.model.AllView', 'name': 'all', 'url': 'http://localhost:8080/'}, {'_class': 'hudson.model.MyView', 'name': 'api-test', 'url': 'http://localhost:8080/view/api-test/'}]

# %%
server.delete_view('EMPTY')
views = server.get_views()
print(views)
# Out:
# [{'_class': 'hudson.model.AllView', 'name': 'all', 'url': 'http://localhost:8080/'}, {'_class': 'hudson.model.MyView', 'name': 'api-test', 'url': 'http://localhost:8080/view/api-test/'}]

# %%
import pprint
plugins = server.get_plugins_info()
pp = pprint.PrettyPrinter()
pp.pprint(plugins)
# Out:
# [{'active': True,
#   'backupVersion': None,
#   'bundled': False,
#   'deleted': False,
#   'dependencies': [{'optional': True,
#                     'shortName': 'bouncycastle-api',
#                     'version': '2.16.0'},
#                    {'optional': True,
#                     'shortName': 'command-launcher',
#                     'version': '1.0'},
#                    {'optional': True,
#                     'shortName': 'jdk-tool',
#                     'version': '1.0'},
#                    {'optional': True,
#                     'shortName': 'trilead-api',
#                     'version': '1.0.4'}],
#   'detached': False,
#   'downgradable': False,
#   'enabled': True,
#   'hasUpdate': False,
#   'longName': 'JavaScript GUI Lib: ACE Editor bundle plugin',
#   'minimumJavaVersion': None,
#   'pinned': False,
#   'requiredCoreVersion': '1.580.1',
#   'shortName': 'ace-editor',
#   'supportsDynamicLoad': 'YES',
#   'url': 'https://plugins.jenkins.io/ace-editor',
#   'version': 1.1},
#  {'active': True,
#   'backupVersion': None,
#   'bundled': False,
#   'deleted': False,
#   'dependencies': [{'optional': False,
#                     'shortName': 'structs',
#                     'version': '1.17'},
#                    {'optional': True,
#                     'shortName': 'trilead-api',
#                     'version': '1.0.4'}],
#   'detached': True,
#   'downgradable': False,
#   'enabled': True,
#   'hasUpdate': False,
#   'longName': 'Ant Plugin',
#   'minimumJavaVersion': '1.8',
#   'pinned': False,
#   'requiredCoreVersion': '2.150.1',
#   'shortName': 'ant',
#   'supportsDynamicLoad': 'MAYBE',
#   'url': 'https://plugins.jenkins.io/ant',
#   'version': 1.11},
#  {'active': True,
#   'backupVersion': None,
#   'bundled': False,
#   'deleted': False,
#   'dependencies': [{'optional': True,
#                     'shortName': 'trilead-api',
#                     'version': '1.0.4'}],
#   'detached': True,
#   'downgradable': False,
#   'enabled': True,
#   'hasUpdate': False,
#   'longName': 'OWASP Markup Formatter Plugin',
#   'minimumJavaVersion': '1.8',
#   'pinned': False,
#   'requiredCoreVersion': '2.121.3',
#   'shortName': 'antisamy-markup-formatter',
#   'supportsDynamicLoad': 'MAYBE',
#   'url': 'https://plugins.jenkins.io/antisamy-markup-formatter',
#   'version': 2.1},
#  {'active': True,
#   'backupVersion': None,
#   'bundled': False,
#   'deleted': False,
#   'dependencies': [{'optional': True,
#                     'shortName': 'command-launcher',
#                     'version': '1.0'},
#                    {'optional': True,
#                     'shortName': 'jdk-tool',
#                     'version': '1.0'},
#                    {'optional': True,
#                     'shortName': 'trilead-api',
#                     'version': '1.0.4'}],
#   'detached': False,
#   'downgradable': False,
#   'enabled': True,
#   'hasUpdate': False,
#   'longName': 'Jenkins Apache HttpComponents Client 4.x API Plugin',
#   'minimumJavaVersion': '1.8',
#   'pinned': False,
#   'requiredCoreVersion': '2.60.3',
#   'shortName': 'apache-httpcomponents-client-4-api',
#   'supportsDynamicLoad': 'YES',
#   'url': 'https://plugins.jenkins.io/apache-httpcomponents-client-4-api',
#   'version': 4.5.10-2.0},
#  {'active': True,
#   'backupVersion': None,
#   'bundled': False,
#   'deleted': False,
#   'dependencies': [{'optional': True,
#                     'shortName': 'command-launcher',
#                     'version': '1.0'},
#                    {'optional': True,
#                     'shortName': 'jdk-tool',
#                     'version': '1.0'},
#                    {'optional': True,
#                     'shortName': 'trilead-api',
#                     'version': '1.0.4'}],
#   'detached': True,
#   'downgradable': False,
#   'enabled': True,
#   'hasUpdate': False,
#   'longName': 'bouncycastle API Plugin',
#   'minimumJavaVersion': '1.8',
#   'pinned': False,
#   'requiredCoreVersion': '2.60.3',
#   'shortName': 'bouncycastle-api',
#   'supportsDynamicLoad': 'YES',
#   'url': 'https://plugins.jenkins.io/bouncycastle-api',
#   'version': 2.18},
#  {'active': True,
#   'backupVersion': None,
#   'bundled': False,
#   'deleted': False,
#   'dependencies': [{'optional': False,
#                     'shortName': 'cloudbees-folder',
#                     'version': '6.12'},
#                    {'optional': False,
#                     'shortName': 'scm-api',
#                     'version': '2.6.3'},
#                    {'optional': True,
#                     'shortName': 'trilead-api',
#                     'version': '1.0.4'}],
#   'detached': False,
#   'downgradable': False,
#   'enabled': True,
#   'hasUpdate': True,
#   'longName': 'Branch API Plugin',
#   'minimumJavaVersion': '1.8',
#   'pinned': False,
#   'requiredCoreVersion': '2.176.4',
#   'shortName': 'branch-api',
#   'supportsDynamicLoad': 'MAYBE',
#   'url': 'https://plugins.jenkins.io/branch-api',
#   'version': 2.5.7},
#  {'active': True,
#   'backupVersion': None,
#   'bundled': False,
#   'deleted': False,
#   'dependencies': [{'optional': False,
#                     'shortName': 'token-macro',
#                     'version': '1.5.1'}],
#   'detached': False,
#   'downgradable': False,
#   'enabled': True,
#   'hasUpdate': False,
#   'longName': 'Build Timeout',
#   'minimumJavaVersion': '1.8',
#   'pinned': False,
#   'requiredCoreVersion': '2.222.1',
#   'shortName': 'build-timeout',
#   'supportsDynamicLoad': 'MAYBE',
#   'url': 'https://plugins.jenkins.io/build-timeout',
#   'version': 1.20},
#  {'active': True,
#   'backupVersion': None,
#   'bundled': False,
#   'deleted': False,
#   'dependencies': [{'optional': True,
#                     'shortName': 'credentials',
#                     'version': '2.3.5'},
#                    {'optional': True,
#                     'shortName': 'trilead-api',
#                     'version': '1.0.4'}],
#   'detached': False,
#   'downgradable': False,
#   'enabled': True,
#   'hasUpdate': False,
#   'longName': 'Folders Plugin',
#   'minimumJavaVersion': '1.8',
#   'pinned': False,
#   'requiredCoreVersion': '2.176.1',
#   'shortName': 'cloudbees-folder',
#   'supportsDynamicLoad': 'MAYBE',
#   'url': 'https://plugins.jenkins.io/cloudbees-folder',
#   'version': 6.14},
#  {'active': True,
#   'backupVersion': '1.2',
#   'bundled': False,
#   'deleted': False,
#   'dependencies': [{'optional': False,
#                     'shortName': 'script-security',
#                     'version': '1.68'},
#                    {'optional': True,
#                     'shortName': 'jdk-tool',
#                     'version': '1.0'},
#                    {'optional': True,
#                     'shortName': 'trilead-api',
#                     'version': '1.0.4'}],
#   'detached': True,
#   'downgradable': True,
#   'enabled': True,
#   'hasUpdate': False,
#   'longName': 'Command Agent Launcher Plugin',
#   'minimumJavaVersion': None,
#   'pinned': False,
#   'requiredCoreVersion': '2.86',
#   'shortName': 'command-launcher',
#   'supportsDynamicLoad': 'MAYBE',
#   'url': 'https://plugins.jenkins.io/command-launcher',
#   'version': 1.4},
#  {'active': True,
#   'backupVersion': '1.23',
#   'bundled': False,
#   'deleted': False,
#   'dependencies': [{'optional': False,
#                     'shortName': 'workflow-step-api',
#                     'version': '2.22'},
#                    {'optional': False,
#                     'shortName': 'credentials',
#                     'version': '2.3.5'},
#                    {'optional': False,
#                     'shortName': 'plain-credentials',
#                     'version': '1.6'},
#                    {'optional': False,
#                     'shortName': 'ssh-credentials',
#                     'version': '1.17.3'},
#                    {'optional': False,
#                     'shortName': 'structs',
#                     'version': '1.20'},
#                    {'optional': True,
#                     'shortName': 'trilead-api',
#                     'version': '1.0.4'}],
#   'detached': False,
#   'downgradable': True,
#   'enabled': True,
#   'hasUpdate': False,
#   'longName': 'Credentials Binding Plugin',
#   'minimumJavaVersion': '1.8',
#   'pinned': False,
#   'requiredCoreVersion': '2.164.3',
#   'shortName': 'credentials-binding',
#   'supportsDynamicLoad': 'MAYBE',
#   'url': 'https://plugins.jenkins.io/credentials-binding',
#   'version': 1.23},
#  {'active': True,
#   'backupVersion': None,
#   'bundled': False,
#   'deleted': False,
#   'dependencies': [{'optional': False,
#                     'shortName': 'structs',
#                     'version': '1.20'},
#                    {'optional': True,
#                     'shortName': 'trilead-api',
#                     'version': '1.0.4'}],
#   'detached': False,
#   'downgradable': False,
#   'enabled': True,
#   'hasUpdate': True,
#   'longName': 'Credentials Plugin',
#   'minimumJavaVersion': '1.8',
#   'pinned': False,
#   'requiredCoreVersion': '2.138.4',
#   'shortName': 'credentials',
#   'supportsDynamicLoad': 'MAYBE',
#   'url': 'https://plugins.jenkins.io/credentials',
#   'version': 2.3.11},
#  {'active': True,
#   'backupVersion': None,
#   'bundled': False,
#   'deleted': False,
#   'dependencies': [{'optional': True,
#                     'shortName': 'trilead-api',
#                     'version': '1.0.4'}],
#   'detached': False,
#   'downgradable': False,
#   'enabled': True,
#   'hasUpdate': False,
#   'longName': 'Display URL API',
#   'minimumJavaVersion': '1.8',
#   'pinned': False,
#   'requiredCoreVersion': '2.176.4',
#   'shortName': 'display-url-api',
#   'supportsDynamicLoad': 'MAYBE',
#   'url': 'https://plugins.jenkins.io/display-url-api',
#   'version': 2.3.3},
#  {'active': True,
#   'backupVersion': None,
#   'bundled': False,
#   'deleted': False,
#   'dependencies': [{'optional': True,
#                     'shortName': 'trilead-api',
#                     'version': '1.0.4'}],
#   'detached': False,
#   'downgradable': False,
#   'enabled': True,
#   'hasUpdate': False,
#   'longName': 'Durable Task Plugin',
#   'minimumJavaVersion': '1.8',
#   'pinned': False,
#   'requiredCoreVersion': '2.150.1',
#   'shortName': 'durable-task',
#   'supportsDynamicLoad': 'MAYBE',
#   'url': 'https://plugins.jenkins.io/durable-task',
#   'version': 1.34},
#  {'active': True,
#   'backupVersion': None,
#   'bundled': False,
#   'deleted': False,
#   'dependencies': [{'optional': False, 'shortName': 'junit', 'version': '1.2'},
#                    {'optional': False,
#                     'shortName': 'mailer',
#                     'version': '1.13'},
#                    {'optional': False,
#                     'shortName': 'matrix-project',
#                     'version': '1.4'},
#                    {'optional': False,
#                     'shortName': 'script-security',
#                     'version': '1.54'},
#                    {'optional': False,
#                     'shortName': 'structs',
#                     'version': '1.17'},
#                    {'optional': False,
#                     'shortName': 'token-macro',
#                     'version': '2.3'},
#                    {'optional': True,
#                     'shortName': 'workflow-job',
#                     'version': '2.12'},
#                    {'optional': True,
#                     'shortName': 'workflow-step-api',
#                     'version': '2.19'},
#                    {'optional': True,
#                     'shortName': 'trilead-api',
#                     'version': '1.0.4'}],
#   'detached': False,
#   'downgradable': False,
#   'enabled': True,
#   'hasUpdate': False,
#   'longName': 'Email Extension Plugin',
#   'minimumJavaVersion': '1.8',
#   'pinned': False,
#   'requiredCoreVersion': '2.138.4',
#   'shortName': 'email-ext',
#   'supportsDynamicLoad': 'MAYBE',
#   'url': 'https://plugins.jenkins.io/email-ext',
#   'version': 2.69},
#  {'active': True,
#   'backupVersion': None,
#   'bundled': False,
#   'deleted': False,
#   'dependencies': [{'optional': False,
#                     'shortName': 'apache-httpcomponents-client-4-api',
#                     'version': '4.5.10-2.0'},
#                    {'optional': False,
#                     'shortName': 'credentials',
#                     'version': '2.3.9'},
#                    {'optional': False,
#                     'shortName': 'jsch',
#                     'version': '0.1.55.2'},
#                    {'optional': False,
#                     'shortName': 'script-security',
#                     'version': '1.73'},
#                    {'optional': False,
#                     'shortName': 'ssh-credentials',
#                     'version': '1.18.1'},
#                    {'optional': False,
#                     'shortName': 'structs',
#                     'version': '1.20'},
#                    {'optional': False,
#                     'shortName': 'trilead-api',
#                     'version': '1.0.8'}],
#   'detached': False,
#   'downgradable': False,
#   'enabled': True,
#   'hasUpdate': False,
#   'longName': 'Jenkins Git client plugin',
#   'minimumJavaVersion': '1.8',
#   'pinned': False,
#   'requiredCoreVersion': '2.204.1',
#   'shortName': 'git-client',
#   'supportsDynamicLoad': 'MAYBE',
#   'url': 'https://plugins.jenkins.io/git-client',
#   'version': 3.3.1},
#  {'active': True,
#   'backupVersion': None,
#   'bundled': False,
#   'deleted': False,
#   'dependencies': [{'optional': False,
#                     'shortName': 'git-client',
#                     'version': '2.7.6'},
#                    {'optional': True,
#                     'shortName': 'trilead-api',
#                     'version': '1.0.4'}],
#   'detached': False,
#   'downgradable': False,
#   'enabled': True,
#   'hasUpdate': False,
#   'longName': 'Jenkins GIT server Plugin',
#   'minimumJavaVersion': '1.8',
#   'pinned': False,
#   'requiredCoreVersion': '2.138.4',
#   'shortName': 'git-server',
#   'supportsDynamicLoad': 'MAYBE',
#   'url': 'https://plugins.jenkins.io/git-server',
#   'version': 1.9},
#  {'active': True,
#   'backupVersion': '4.3.0',
#   'bundled': False,
#   'deleted': False,
#   'dependencies': [{'optional': False,
#                     'shortName': 'workflow-scm-step',
#                     'version': '2.11'},
#                    {'optional': False,
#                     'shortName': 'workflow-step-api',
#                     'version': '2.22'},
#                    {'optional': False,
#                     'shortName': 'credentials',
#                     'version': '2.3.7'},
#                    {'optional': False,
#                     'shortName': 'git-client',
#                     'version': '3.2.1'},
#                    {'optional': False,
#                     'shortName': 'mailer',
#                     'version': '1.32'},
#                    {'optional': False,
#                     'shortName': 'scm-api',
#                     'version': '2.6.3'},
#                    {'optional': False,
#                     'shortName': 'script-security',
#                     'version': '1.73'},
#                    {'optional': False,
#                     'shortName': 'ssh-credentials',
#                     'version': '1.18.1'},
#                    {'optional': False,
#                     'shortName': 'structs',
#                     'version': '1.20'},
#                    {'optional': True,
#                     'shortName': 'matrix-project',
#                     'version': '1.14'},
#                    {'optional': True,
#                     'shortName': 'token-macro',
#                     'version': '2.12'}],
#   'detached': False,
#   'downgradable': True,
#   'enabled': True,
#   'hasUpdate': False,
#   'longName': 'Jenkins Git plugin',
#   'minimumJavaVersion': '1.8',
#   'pinned': False,
#   'requiredCoreVersion': '2.204.1',
#   'shortName': 'git',
#   'supportsDynamicLoad': 'MAYBE',
#   'url': 'https://plugins.jenkins.io/git',
#   'version': 4.3.0},
#  {'active': True,
#   'backupVersion': '1.114.3',
#   'bundled': False,
#   'deleted': False,
#   'dependencies': [{'optional': False,
#                     'shortName': 'okhttp-api',
#                     'version': '3.14.9'},
#                    {'optional': False,
#                     'shortName': 'jackson2-api',
#                     'version': '2.10.2'},
#                    {'optional': True,
#                     'shortName': 'trilead-api',
#                     'version': '1.0.4'}],
#   'detached': False,
#   'downgradable': True,
#   'enabled': True,
#   'hasUpdate': False,
#   'longName': 'GitHub API Plugin',
#   'minimumJavaVersion': '1.8',
#   'pinned': False,
#   'requiredCoreVersion': '2.164.3',
#   'shortName': 'github-api',
#   'supportsDynamicLoad': 'YES',
#   'url': 'https://plugins.jenkins.io/github-api',
#   'version': 1.115},
#  {'active': True,
#   'backupVersion': None,
#   'bundled': False,
#   'deleted': False,
#   'dependencies': [{'optional': False,
#                     'shortName': 'github',
#                     'version': '1.29.3'},
#                    {'optional': False,
#                     'shortName': 'github-api',
#                     'version': '1.111.4'},
#                    {'optional': False,
#                     'shortName': 'jackson2-api',
#                     'version': '2.10.2'},
#                    {'optional': True,
#                     'shortName': 'trilead-api',
#                     'version': '1.0.4'}],
#   'detached': False,
#   'downgradable': False,
#   'enabled': True,
#   'hasUpdate': False,
#   'longName': 'GitHub Branch Source Plugin',
#   'minimumJavaVersion': '1.8',
#   'pinned': False,
#   'requiredCoreVersion': '2.164.3',
#   'shortName': 'github-branch-source',
#   'supportsDynamicLoad': 'MAYBE',
#   'url': 'https://plugins.jenkins.io/github-branch-source',
#   'version': 2.8.2},
#  {'active': True,
#   'backupVersion': None,
#   'bundled': False,
#   'deleted': False,
#   'dependencies': [{'optional': False,
#                     'shortName': 'credentials',
#                     'version': '2.1.13'},
#                    {'optional': False,
#                     'shortName': 'display-url-api',
#                     'version': '2.0'},
#                    {'optional': False, 'shortName': 'git', 'version': '3.4.0'},
#                    {'optional': False,
#                     'shortName': 'github-api',
#                     'version': '1.114.2'},
#                    {'optional': False,
#                     'shortName': 'plain-credentials',
#                     'version': '1.1'},
#                    {'optional': False,
#                     'shortName': 'scm-api',
#                     'version': '2.2.0'},
#                    {'optional': False,
#                     'shortName': 'structs',
#                     'version': '1.17'},
#                    {'optional': False,
#                     'shortName': 'token-macro',
#                     'version': '1.12.1'},
#                    {'optional': True,
#                     'shortName': 'trilead-api',
#                     'version': '1.0.4'}],
#   'detached': False,
#   'downgradable': False,
#   'enabled': True,
#   'hasUpdate': False,
#   'longName': 'GitHub plugin',
#   'minimumJavaVersion': '1.8',
#   'pinned': False,
#   'requiredCoreVersion': '2.164.3',
#   'shortName': 'github',
#   'supportsDynamicLoad': 'MAYBE',
#   'url': 'https://plugins.jenkins.io/github',
#   'version': 1.31.0},
#  {'active': True,
#   'backupVersion': None,
#   'bundled': False,
#   'deleted': False,
#   'dependencies': [{'optional': False,
#                     'shortName': 'structs',
#                     'version': '1.20'},
#                    {'optional': False,
#                     'shortName': 'workflow-api',
#                     'version': '2.37'},
#                    {'optional': False,
#                     'shortName': 'workflow-cps',
#                     'version': '2.74'},
#                    {'optional': False,
#                     'shortName': 'workflow-job',
#                     'version': '2.35'},
#                    {'optional': False,
#                     'shortName': 'workflow-basic-steps',
#                     'version': '2.16.1'},
#                    {'optional': False,
#                     'shortName': 'workflow-durable-task-step',
#                     'version': '2.28'},
#                    {'optional': False,
#                     'shortName': 'workflow-step-api',
#                     'version': '2.20'},
#                    {'optional': True,
#                     'shortName': 'trilead-api',
#                     'version': '1.0.4'}],
#   'detached': False,
#   'downgradable': False,
#   'enabled': True,
#   'hasUpdate': False,
#   'longName': 'Gradle Plugin',
#   'minimumJavaVersion': '1.8',
#   'pinned': False,
#   'requiredCoreVersion': '2.138.4',
#   'shortName': 'gradle',
#   'supportsDynamicLoad': 'MAYBE',
#   'url': 'https://plugins.jenkins.io/gradle',
#   'version': 1.36},
#  {'active': True,
#   'backupVersion': None,
#   'bundled': False,
#   'deleted': False,
#   'dependencies': [{'optional': True,
#                     'shortName': 'bouncycastle-api',
#                     'version': '2.16.0'},
#                    {'optional': True,
#                     'shortName': 'command-launcher',
#                     'version': '1.0'},
#                    {'optional': True,
#                     'shortName': 'jdk-tool',
#                     'version': '1.0'},
#                    {'optional': True,
#                     'shortName': 'trilead-api',
#                     'version': '1.0.4'}],
#   'detached': False,
#   'downgradable': False,
#   'enabled': True,
#   'hasUpdate': False,
#   'longName': 'JavaScript GUI Lib: Handlebars bundle plugin',
#   'minimumJavaVersion': None,
#   'pinned': False,
#   'requiredCoreVersion': '1.580.1',
#   'shortName': 'handlebars',
#   'supportsDynamicLoad': 'YES',
#   'url': 'https://plugins.jenkins.io/handlebars',
#   'version': 1.1.1},
#  {'active': True,
#   'backupVersion': None,
#   'bundled': False,
#   'deleted': False,
#   'dependencies': [{'optional': False,
#                     'shortName': 'snakeyaml-api',
#                     'version': '1.26.3'},
#                    {'optional': True,
#                     'shortName': 'trilead-api',
#                     'version': '1.0.4'}],
#   'detached': False,
#   'downgradable': False,
#   'enabled': True,
#   'hasUpdate': False,
#   'longName': 'Jackson 2 API Plugin',
#   'minimumJavaVersion': '1.8',
#   'pinned': False,
#   'requiredCoreVersion': '2.164.3',
#   'shortName': 'jackson2-api',
#   'supportsDynamicLoad': 'YES',
#   'url': 'https://plugins.jenkins.io/jackson2-api',
#   'version': 2.11.1},
#  {'active': True,
#   'backupVersion': None,
#   'bundled': False,
#   'deleted': False,
#   'dependencies': [{'optional': True,
#                     'shortName': 'trilead-api',
#                     'version': '1.0.4'}],
#   'detached': True,
#   'downgradable': False,
#   'enabled': True,
#   'hasUpdate': False,
#   'longName': 'Oracle Java SE Development Kit Installer Plugin',
#   'minimumJavaVersion': None,
#   'pinned': False,
#   'requiredCoreVersion': '2.112',
#   'shortName': 'jdk-tool',
#   'supportsDynamicLoad': 'MAYBE',
#   'url': 'https://plugins.jenkins.io/jdk-tool',
#   'version': 1.4},
#  {'active': True,
#   'backupVersion': None,
#   'bundled': False,
#   'deleted': False,
#   'dependencies': [{'optional': True,
#                     'shortName': 'bouncycastle-api',
#                     'version': '2.16.0'},
#                    {'optional': True,
#                     'shortName': 'command-launcher',
#                     'version': '1.0'},
#                    {'optional': True,
#                     'shortName': 'jdk-tool',
#                     'version': '1.0'},
#                    {'optional': True,
#                     'shortName': 'trilead-api',
#                     'version': '1.0.4'}],
#   'detached': False,
#   'downgradable': False,
#   'enabled': True,
#   'hasUpdate': False,
#   'longName': 'JavaScript GUI Lib: jQuery bundles (jQuery and jQuery UI) '
#               'plugin',
#   'minimumJavaVersion': None,
#   'pinned': False,
#   'requiredCoreVersion': '1.580.1',
#   'shortName': 'jquery-detached',
#   'supportsDynamicLoad': 'YES',
#   'url': 'https://plugins.jenkins.io/jquery-detached',
#   'version': 1.2.1},
#  {'active': True,
#   'backupVersion': None,
#   'bundled': False,
#   'deleted': False,
#   'dependencies': [{'optional': False,
#                     'shortName': 'ssh-credentials',
#                     'version': '1.14'},
#                    {'optional': False,
#                     'shortName': 'trilead-api',
#                     'version': '1.0.5'}],
#   'detached': False,
#   'downgradable': False,
#   'enabled': True,
#   'hasUpdate': False,
#   'longName': 'Jenkins JSch dependency plugin',
#   'minimumJavaVersion': '1.8',
#   'pinned': False,
#   'requiredCoreVersion': '2.190.1',
#   'shortName': 'jsch',
#   'supportsDynamicLoad': 'MAYBE',
#   'url': 'https://plugins.jenkins.io/jsch',
#   'version': 0.1.55.2},
#  {'active': True,
#   'backupVersion': None,
#   'bundled': False,
#   'deleted': False,
#   'dependencies': [{'optional': False,
#                     'shortName': 'workflow-api',
#                     'version': '2.40'},
#                    {'optional': False,
#                     'shortName': 'workflow-step-api',
#                     'version': '2.22'},
#                    {'optional': False,
#                     'shortName': 'script-security',
#                     'version': '1.71'},
#                    {'optional': False,
#                     'shortName': 'structs',
#                     'version': '1.20'},
#                    {'optional': True,
#                     'shortName': 'trilead-api',
#                     'version': '1.0.4'}],
#   'detached': True,
#   'downgradable': False,
#   'enabled': True,
#   'hasUpdate': False,
#   'longName': 'JUnit Plugin',
#   'minimumJavaVersion': '1.8',
#   'pinned': False,
#   'requiredCoreVersion': '2.164.3',
#   'shortName': 'junit',
#   'supportsDynamicLoad': 'MAYBE',
#   'url': 'https://plugins.jenkins.io/junit',
#   'version': 1.29},
#  {'active': True,
#   'backupVersion': None,
#   'bundled': False,
#   'deleted': False,
#   'dependencies': [{'optional': False,
#                     'shortName': 'mailer',
#                     'version': '1.20'},
#                    {'optional': True,
#                     'shortName': 'command-launcher',
#                     'version': '1.0'},
#                    {'optional': True,
#                     'shortName': 'jdk-tool',
#                     'version': '1.0'},
#                    {'optional': True,
#                     'shortName': 'trilead-api',
#                     'version': '1.0.4'}],
#   'detached': True,
#   'downgradable': False,
#   'enabled': True,
#   'hasUpdate': False,
#   'longName': 'LDAP Plugin',
#   'minimumJavaVersion': '1.8',
#   'pinned': False,
#   'requiredCoreVersion': '2.60.3',
#   'shortName': 'ldap',
#   'supportsDynamicLoad': 'MAYBE',
#   'url': 'https://plugins.jenkins.io/ldap',
#   'version': 1.24},
#  {'active': True,
#   'backupVersion': None,
#   'bundled': False,
#   'deleted': False,
#   'dependencies': [{'optional': False,
#                     'shortName': 'workflow-support',
#                     'version': '3.4'},
#                    {'optional': False,
#                     'shortName': 'mailer',
#                     'version': '1.18'},
#                    {'optional': False,
#                     'shortName': 'matrix-project',
#                     'version': '1.14'},
#                    {'optional': False,
#                     'shortName': 'script-security',
#                     'version': '1.62'},
#                    {'optional': False,
#                     'shortName': 'structs',
#                     'version': '1.20'},
#                    {'optional': True,
#                     'shortName': 'trilead-api',
#                     'version': '1.0.4'}],
#   'detached': False,
#   'downgradable': False,
#   'enabled': True,
#   'hasUpdate': False,
#   'longName': 'Lockable Resources plugin',
#   'minimumJavaVersion': '1.8',
#   'pinned': False,
#   'requiredCoreVersion': '2.138.4',
#   'shortName': 'lockable-resources',
#   'supportsDynamicLoad': 'MAYBE',
#   'url': 'https://plugins.jenkins.io/lockable-resources',
#   'version': 2.8},
#  {'active': True,
#   'backupVersion': None,
#   'bundled': False,
#   'deleted': False,
#   'dependencies': [{'optional': False,
#                     'shortName': 'display-url-api',
#                     'version': '2.3.1'},
#                    {'optional': True,
#                     'shortName': 'trilead-api',
#                     'version': '1.0.4'}],
#   'detached': True,
#   'downgradable': False,
#   'enabled': True,
#   'hasUpdate': False,
#   'longName': 'Jenkins Mailer Plugin',
#   'minimumJavaVersion': '1.8',
#   'pinned': False,
#   'requiredCoreVersion': '2.150.1',
#   'shortName': 'mailer',
#   'supportsDynamicLoad': 'MAYBE',
#   'url': 'https://plugins.jenkins.io/mailer',
#   'version': 1.32},
#  {'active': True,
#   'backupVersion': None,
#   'bundled': False,
#   'deleted': False,
#   'dependencies': [{'optional': True,
#                     'shortName': 'cloudbees-folder',
#                     'version': '6.1.0'}],
#   'detached': True,
#   'downgradable': False,
#   'enabled': True,
#   'hasUpdate': False,
#   'longName': 'Matrix Authorization Strategy Plugin',
#   'minimumJavaVersion': '1.8',
#   'pinned': False,
#   'requiredCoreVersion': '2.222.1',
#   'shortName': 'matrix-auth',
#   'supportsDynamicLoad': 'MAYBE',
#   'url': 'https://plugins.jenkins.io/matrix-auth',
#   'version': 2.6.2},
#  {'active': True,
#   'backupVersion': None,
#   'bundled': False,
#   'deleted': False,
#   'dependencies': [{'optional': False, 'shortName': 'junit', 'version': '1.29'},
#                    {'optional': False,
#                     'shortName': 'script-security',
#                     'version': '1.71'},
#                    {'optional': True,
#                     'shortName': 'trilead-api',
#                     'version': '1.0.4'}],
#   'detached': True,
#   'downgradable': False,
#   'enabled': True,
#   'hasUpdate': False,
#   'longName': 'Matrix Project Plugin',
#   'minimumJavaVersion': '1.8',
#   'pinned': False,
#   'requiredCoreVersion': '2.164.3',
#   'shortName': 'matrix-project',
#   'supportsDynamicLoad': 'MAYBE',
#   'url': 'https://plugins.jenkins.io/matrix-project',
#   'version': 1.17},
#  {'active': True,
#   'backupVersion': None,
#   'bundled': False,
#   'deleted': False,
#   'dependencies': [{'optional': True,
#                     'shortName': 'bouncycastle-api',
#                     'version': '2.16.0'},
#                    {'optional': True,
#                     'shortName': 'command-launcher',
#                     'version': '1.0'},
#                    {'optional': True,
#                     'shortName': 'jdk-tool',
#                     'version': '1.0'},
#                    {'optional': True,
#                     'shortName': 'trilead-api',
#                     'version': '1.0.4'}],
#   'detached': False,
#   'downgradable': False,
#   'enabled': True,
#   'hasUpdate': False,
#   'longName': 'JavaScript GUI Lib: Moment.js bundle plugin',
#   'minimumJavaVersion': None,
#   'pinned': False,
#   'requiredCoreVersion': '1.580.1',
#   'shortName': 'momentjs',
#   'supportsDynamicLoad': 'YES',
#   'url': 'https://plugins.jenkins.io/momentjs',
#   'version': 1.1.1},
#  {'active': True,
#   'backupVersion': None,
#   'bundled': False,
#   'deleted': False,
#   'dependencies': [{'optional': True,
#                     'shortName': 'trilead-api',
#                     'version': '1.0.4'}],
#   'detached': False,
#   'downgradable': False,
#   'enabled': True,
#   'hasUpdate': False,
#   'longName': 'OkHttp Plugin',
#   'minimumJavaVersion': '1.8',
#   'pinned': False,
#   'requiredCoreVersion': '2.164.3',
#   'shortName': 'okhttp-api',
#   'supportsDynamicLoad': 'YES',
#   'url': 'https://plugins.jenkins.io/okhttp-api',
#   'version': 3.14.9},
#  {'active': True,
#   'backupVersion': None,
#   'bundled': False,
#   'deleted': False,
#   'dependencies': [{'optional': True,
#                     'shortName': 'trilead-api',
#                     'version': '1.0.4'}],
#   'detached': True,
#   'downgradable': False,
#   'enabled': True,
#   'hasUpdate': False,
#   'longName': 'PAM Authentication plugin',
#   'minimumJavaVersion': '1.8',
#   'pinned': False,
#   'requiredCoreVersion': '2.138.4',
#   'shortName': 'pam-auth',
#   'supportsDynamicLoad': 'MAYBE',
#   'url': 'https://plugins.jenkins.io/pam-auth',
#   'version': 1.6},
#  {'active': True,
#   'backupVersion': None,
#   'bundled': False,
#   'deleted': False,
#   'dependencies': [{'optional': False,
#                     'shortName': 'workflow-api',
#                     'version': '2.33'},
#                    {'optional': False,
#                     'shortName': 'workflow-step-api',
#                     'version': '2.22'},
#                    {'optional': False,
#                     'shortName': 'workflow-support',
#                     'version': '3.1'},
#                    {'optional': False,
#                     'shortName': 'script-security',
#                     'version': '1.50'},
#                    {'optional': True,
#                     'shortName': 'trilead-api',
#                     'version': '1.0.4'}],
#   'detached': False,
#   'downgradable': False,
#   'enabled': True,
#   'hasUpdate': False,
#   'longName': 'Pipeline: Build Step',
#   'minimumJavaVersion': '1.8',
#   'pinned': False,
#   'requiredCoreVersion': '2.138.4',
#   'shortName': 'pipeline-build-step',
#   'supportsDynamicLoad': 'MAYBE',
#   'url': 'https://plugins.jenkins.io/pipeline-build-step',
#   'version': 2.12},
#  {'active': True,
#   'backupVersion': None,
#   'bundled': False,
#   'deleted': False,
#   'dependencies': [{'optional': False,
#                     'shortName': 'workflow-cps-global-lib',
#                     'version': '2.5'},
#                    {'optional': False, 'shortName': 'git', 'version': '3.0.2'},
#                    {'optional': True,
#                     'shortName': 'bouncycastle-api',
#                     'version': '2.16.0'},
#                    {'optional': True,
#                     'shortName': 'command-launcher',
#                     'version': '1.0'},
#                    {'optional': True,
#                     'shortName': 'jdk-tool',
#                     'version': '1.0'},
#                    {'optional': True,
#                     'shortName': 'trilead-api',
#                     'version': '1.0.4'}],
#   'detached': False,
#   'downgradable': False,
#   'enabled': True,
#   'hasUpdate': False,
#   'longName': 'Pipeline: GitHub Groovy Libraries',
#   'minimumJavaVersion': None,
#   'pinned': False,
#   'requiredCoreVersion': '1.642.3',
#   'shortName': 'pipeline-github-lib',
#   'supportsDynamicLoad': 'MAYBE',
#   'url': 'https://plugins.jenkins.io/pipeline-github-lib',
#   'version': 1.0},
#  {'active': True,
#   'backupVersion': None,
#   'bundled': False,
#   'deleted': False,
#   'dependencies': [{'optional': False,
#                     'shortName': 'workflow-api',
#                     'version': '2.34'},
#                    {'optional': False,
#                     'shortName': 'workflow-cps',
#                     'version': '2.65'},
#                    {'optional': False,
#                     'shortName': 'workflow-job',
#                     'version': '2.32'},
#                    {'optional': False,
#                     'shortName': 'workflow-step-api',
#                     'version': '2.19'},
#                    {'optional': False,
#                     'shortName': 'workflow-support',
#                     'version': '3.2'},
#                    {'optional': False,
#                     'shortName': 'pipeline-input-step',
#                     'version': '2.8'},
#                    {'optional': False,
#                     'shortName': 'pipeline-stage-step',
#                     'version': '2.3'},
#                    {'optional': False,
#                     'shortName': 'scm-api',
#                     'version': '2.2.7'},
#                    {'optional': False,
#                     'shortName': 'structs',
#                     'version': '1.17'},
#                    {'optional': True,
#                     'shortName': 'trilead-api',
#                     'version': '1.0.4'}],
#   'detached': False,
#   'downgradable': False,
#   'enabled': True,
#   'hasUpdate': False,
#   'longName': 'Pipeline Graph Analysis Plugin',
#   'minimumJavaVersion': '1.8',
#   'pinned': False,
#   'requiredCoreVersion': '2.138.4',
#   'shortName': 'pipeline-graph-analysis',
#   'supportsDynamicLoad': 'YES',
#   'url': 'https://plugins.jenkins.io/pipeline-graph-analysis',
#   'version': 1.10},
#  {'active': True,
#   'backupVersion': None,
#   'bundled': False,
#   'deleted': False,
#   'dependencies': [{'optional': False,
#                     'shortName': 'workflow-api',
#                     'version': '2.35'},
#                    {'optional': False,
#                     'shortName': 'workflow-step-api',
#                     'version': '2.20'},
#                    {'optional': False,
#                     'shortName': 'workflow-support',
#                     'version': '3.3'},
#                    {'optional': False,
#                     'shortName': 'credentials',
#                     'version': '2.3.0'},
#                    {'optional': True,
#                     'shortName': 'trilead-api',
#                     'version': '1.0.4'}],
#   'detached': False,
#   'downgradable': False,
#   'enabled': True,
#   'hasUpdate': False,
#   'longName': 'Pipeline: Input Step',
#   'minimumJavaVersion': '1.8',
#   'pinned': False,
#   'requiredCoreVersion': '2.138.4',
#   'shortName': 'pipeline-input-step',
#   'supportsDynamicLoad': 'MAYBE',
#   'url': 'https://plugins.jenkins.io/pipeline-input-step',
#   'version': 2.11},
#  {'active': True,
#   'backupVersion': None,
#   'bundled': False,
#   'deleted': False,
#   'dependencies': [{'optional': False,
#                     'shortName': 'workflow-api',
#                     'version': '2.11'},
#                    {'optional': False,
#                     'shortName': 'workflow-step-api',
#                     'version': '2.9'},
#                    {'optional': True,
#                     'shortName': 'bouncycastle-api',
#                     'version': '2.16.0'},
#                    {'optional': True,
#                     'shortName': 'command-launcher',
#                     'version': '1.0'},
#                    {'optional': True,
#                     'shortName': 'jdk-tool',
#                     'version': '1.0'},
#                    {'optional': True,
#                     'shortName': 'trilead-api',
#                     'version': '1.0.4'}],
#   'detached': False,
#   'downgradable': False,
#   'enabled': True,
#   'hasUpdate': False,
#   'longName': 'Pipeline: Milestone Step',
#   'minimumJavaVersion': None,
#   'pinned': False,
#   'requiredCoreVersion': '1.642.3',
#   'shortName': 'pipeline-milestone-step',
#   'supportsDynamicLoad': 'MAYBE',
#   'url': 'https://plugins.jenkins.io/pipeline-milestone-step',
#   'version': 1.3.1},
#  {'active': True,
#   'backupVersion': None,
#   'bundled': False,
#   'deleted': False,
#   'dependencies': [{'optional': False,
#                     'shortName': 'workflow-step-api',
#                     'version': '2.22'},
#                    {'optional': False,
#                     'shortName': 'jackson2-api',
#                     'version': '2.9.8'},
#                    {'optional': False,
#                     'shortName': 'structs',
#                     'version': '1.20'},
#                    {'optional': True,
#                     'shortName': 'trilead-api',
#                     'version': '1.0.4'}],
#   'detached': False,
#   'downgradable': False,
#   'enabled': True,
#   'hasUpdate': False,
#   'longName': 'Pipeline: Model API',
#   'minimumJavaVersion': '1.8',
#   'pinned': False,
#   'requiredCoreVersion': '2.176.4',
#   'shortName': 'pipeline-model-api',
#   'supportsDynamicLoad': 'MAYBE',
#   'url': 'https://plugins.jenkins.io/pipeline-model-api',
#   'version': 1.7.1},
#  {'active': True,
#   'backupVersion': None,
#   'bundled': False,
#   'deleted': False,
#   'dependencies': [{'optional': False,
#                     'shortName': 'workflow-api',
#                     'version': '2.40'},
#                    {'optional': False,
#                     'shortName': 'workflow-basic-steps',
#                     'version': '2.20'},
#                    {'optional': False,
#                     'shortName': 'workflow-cps-global-lib',
#                     'version': '2.16'},
#                    {'optional': False,
#                     'shortName': 'workflow-cps',
#                     'version': '2.80'},
#                    {'optional': False,
#                     'shortName': 'workflow-durable-task-step',
#                     'version': '2.35'},
#                    {'optional': False,
#                     'shortName': 'workflow-multibranch',
#                     'version': '2.16'},
#                    {'optional': False,
#                     'shortName': 'workflow-scm-step',
#                     'version': '2.11'},
#                    {'optional': False,
#                     'shortName': 'workflow-support',
#                     'version': '3.4'},
#                    {'optional': False,
#                     'shortName': 'credentials-binding',
#                     'version': '1.23'},
#                    {'optional': False,
#                     'shortName': 'credentials',
#                     'version': '2.3.7'},
#                    {'optional': False,
#                     'shortName': 'git-client',
#                     'version': '3.2.1'},
#                    {'optional': False,
#                     'shortName': 'mailer',
#                     'version': '1.32'},
#                    {'optional': False,
#                     'shortName': 'pipeline-input-step',
#                     'version': '2.11'},
#                    {'optional': False,
#                     'shortName': 'pipeline-stage-step',
#                     'version': '2.3'},
#                    {'optional': False,
#                     'shortName': 'scm-api',
#                     'version': '2.6.3'},
#                    {'optional': False,
#                     'shortName': 'pipeline-model-api',
#                     'version': '1.7.1'},
#                    {'optional': False,
#                     'shortName': 'pipeline-model-extensions',
#                     'version': '1.7.1'},
#                    {'optional': False,
#                     'shortName': 'pipeline-stage-tags-metadata',
#                     'version': '1.7.1'},
#                    {'optional': True,
#                     'shortName': 'trilead-api',
#                     'version': '1.0.4'}],
#   'detached': False,
#   'downgradable': False,
#   'enabled': True,
#   'hasUpdate': False,
#   'longName': 'Pipeline: Declarative',
#   'minimumJavaVersion': '1.8',
#   'pinned': False,
#   'requiredCoreVersion': '2.176.4',
#   'shortName': 'pipeline-model-definition',
#   'supportsDynamicLoad': 'MAYBE',
#   'url': 'https://plugins.jenkins.io/pipeline-model-definition',
#   'version': 1.7.1},
#  {'active': True,
#   'backupVersion': None,
#   'bundled': False,
#   'deleted': False,
#   'dependencies': [{'optional': False,
#                     'shortName': 'workflow-cps',
#                     'version': '2.80'},
#                    {'optional': False,
#                     'shortName': 'workflow-job',
#                     'version': '2.39'},
#                    {'optional': False,
#                     'shortName': 'credentials-binding',
#                     'version': '1.23'},
#                    {'optional': False,
#                     'shortName': 'credentials',
#                     'version': '2.3.7'},
#                    {'optional': False,
#                     'shortName': 'pipeline-stage-step',
#                     'version': '2.3'},
#                    {'optional': False,
#                     'shortName': 'pipeline-model-api',
#                     'version': '1.7.1'},
#                    {'optional': True,
#                     'shortName': 'trilead-api',
#                     'version': '1.0.4'}],
#   'detached': False,
#   'downgradable': False,
#   'enabled': True,
#   'hasUpdate': False,
#   'longName': 'Pipeline: Declarative Extension Points API',
#   'minimumJavaVersion': '1.8',
#   'pinned': False,
#   'requiredCoreVersion': '2.176.4',
#   'shortName': 'pipeline-model-extensions',
#   'supportsDynamicLoad': 'YES',
#   'url': 'https://plugins.jenkins.io/pipeline-model-extensions',
#   'version': 1.7.1},
#  {'active': True,
#   'backupVersion': None,
#   'bundled': False,
#   'deleted': False,
#   'dependencies': [{'optional': False,
#                     'shortName': 'workflow-api',
#                     'version': '2.24'},
#                    {'optional': False,
#                     'shortName': 'workflow-job',
#                     'version': '2.12'},
#                    {'optional': False,
#                     'shortName': 'workflow-step-api',
#                     'version': '2.14'},
#                    {'optional': False,
#                     'shortName': 'workflow-support',
#                     'version': '2.14'},
#                    {'optional': False,
#                     'shortName': 'jackson2-api',
#                     'version': '2.9.9.1'},
#                    {'optional': False,
#                     'shortName': 'pipeline-graph-analysis',
#                     'version': '1.4'},
#                    {'optional': False,
#                     'shortName': 'pipeline-input-step',
#                     'version': '2.8'},
#                    {'optional': False,
#                     'shortName': 'pipeline-stage-step',
#                     'version': '2.3'},
#                    {'optional': True,
#                     'shortName': 'command-launcher',
#                     'version': '1.0'},
#                    {'optional': True,
#                     'shortName': 'jdk-tool',
#                     'version': '1.0'},
#                    {'optional': True,
#                     'shortName': 'trilead-api',
#                     'version': '1.0.4'}],
#   'detached': False,
#   'downgradable': False,
#   'enabled': True,
#   'hasUpdate': False,
#   'longName': 'Pipeline: REST API Plugin',
#   'minimumJavaVersion': '1.8',
#   'pinned': False,
#   'requiredCoreVersion': '2.60.3',
#   'shortName': 'pipeline-rest-api',
#   'supportsDynamicLoad': 'MAYBE',
#   'url': 'https://plugins.jenkins.io/pipeline-rest-api',
#   'version': 2.13},
#  {'active': True,
#   'backupVersion': None,
#   'bundled': False,
#   'deleted': False,
#   'dependencies': [{'optional': False,
#                     'shortName': 'workflow-api',
#                     'version': '2.40'},
#                    {'optional': False,
#                     'shortName': 'workflow-step-api',
#                     'version': '2.22'},
#                    {'optional': True,
#                     'shortName': 'trilead-api',
#                     'version': '1.0.4'}],
#   'detached': False,
#   'downgradable': False,
#   'enabled': True,
#   'hasUpdate': False,
#   'longName': 'Pipeline: Stage Step',
#   'minimumJavaVersion': '1.8',
#   'pinned': False,
#   'requiredCoreVersion': '2.176.4',
#   'shortName': 'pipeline-stage-step',
#   'supportsDynamicLoad': 'MAYBE',
#   'url': 'https://plugins.jenkins.io/pipeline-stage-step',
#   'version': 2.5},
#  {'active': True,
#   'backupVersion': None,
#   'bundled': False,
#   'deleted': False,
#   'dependencies': [{'optional': False,
#                     'shortName': 'workflow-api',
#                     'version': '2.40'},
#                    {'optional': True,
#                     'shortName': 'trilead-api',
#                     'version': '1.0.4'}],
#   'detached': False,
#   'downgradable': False,
#   'enabled': True,
#   'hasUpdate': False,
#   'longName': 'Pipeline: Stage Tags Metadata',
#   'minimumJavaVersion': '1.8',
#   'pinned': False,
#   'requiredCoreVersion': '2.176.4',
#   'shortName': 'pipeline-stage-tags-metadata',
#   'supportsDynamicLoad': 'MAYBE',
#   'url': 'https://plugins.jenkins.io/pipeline-stage-tags-metadata',
#   'version': 1.7.1},
#  {'active': True,
#   'backupVersion': None,
#   'bundled': False,
#   'deleted': False,
#   'dependencies': [{'optional': False,
#                     'shortName': 'pipeline-rest-api',
#                     'version': '2.13'},
#                    {'optional': False,
#                     'shortName': 'workflow-api',
#                     'version': '2.24'},
#                    {'optional': False,
#                     'shortName': 'workflow-job',
#                     'version': '2.12'},
#                    {'optional': False,
#                     'shortName': 'handlebars',
#                     'version': '1.1.1'},
#                    {'optional': False,
#                     'shortName': 'jquery-detached',
#                     'version': '1.2.1'},
#                    {'optional': False,
#                     'shortName': 'momentjs',
#                     'version': '1.1'},
#                    {'optional': True,
#                     'shortName': 'command-launcher',
#                     'version': '1.0'},
#                    {'optional': True,
#                     'shortName': 'jdk-tool',
#                     'version': '1.0'},
#                    {'optional': True,
#                     'shortName': 'trilead-api',
#                     'version': '1.0.4'}],
#   'detached': False,
#   'downgradable': False,
#   'enabled': True,
#   'hasUpdate': False,
#   'longName': 'Pipeline: Stage View Plugin',
#   'minimumJavaVersion': '1.8',
#   'pinned': False,
#   'requiredCoreVersion': '2.60.3',
#   'shortName': 'pipeline-stage-view',
#   'supportsDynamicLoad': 'MAYBE',
#   'url': 'https://plugins.jenkins.io/pipeline-stage-view',
#   'version': 2.13},
#  {'active': True,
#   'backupVersion': None,
#   'bundled': False,
#   'deleted': False,
# ...
#                     'version': '2.56'},
#                    {'optional': False,
#                     'shortName': 'workflow-durable-task-step',
#                     'version': '2.22'},
#                    {'optional': False,
#                     'shortName': 'workflow-job',
#                     'version': '2.25'},
#                    {'optional': False,
#                     'shortName': 'workflow-multibranch',
#                     'version': '2.20'},
#                    {'optional': False,
#                     'shortName': 'workflow-scm-step',
#                     'version': '2.6'},
#                    {'optional': False,
#                     'shortName': 'workflow-step-api',
#                     'version': '2.16'},
#                    {'optional': False,
#                     'shortName': 'workflow-support',
#                     'version': '2.20'},
#                    {'optional': False,
#                     'shortName': 'cloudbees-folder',
#                     'version': '6.6'},
#                    {'optional': False,
#                     'shortName': 'credentials',
#                     'version': '2.1.18'},
#                    {'optional': False,
#                     'shortName': 'git-client',
#                     'version': '2.7.3'},
#                    {'optional': False,
#                     'shortName': 'jackson2-api',
#                     'version': '2.8.11.3'},
#                    {'optional': False,
#                     'shortName': 'pipeline-build-step',
#                     'version': '2.7'},
#                    {'optional': False,
#                     'shortName': 'pipeline-input-step',
#                     'version': '2.8'},
#                    {'optional': False,
#                     'shortName': 'pipeline-milestone-step',
#                     'version': '1.3.1'},
#                    {'optional': False,
#                     'shortName': 'pipeline-stage-step',
#                     'version': '2.3'},
#                    {'optional': False,
#                     'shortName': 'scm-api',
#                     'version': '2.2.8'},
#                    {'optional': False,
#                     'shortName': 'structs',
#                     'version': '1.15'},
#                    {'optional': False,
#                     'shortName': 'pipeline-model-definition',
#                     'version': '1.3.2'},
#                    {'optional': True,
#                     'shortName': 'trilead-api',
#                     'version': '1.0.4'}],
#   'detached': False,
#   'downgradable': False,
#   'enabled': True,
#   'hasUpdate': False,
#   'longName': 'Pipeline',
#   'minimumJavaVersion': None,
#   'pinned': False,
#   'requiredCoreVersion': '2.130',
#   'shortName': 'workflow-aggregator',
#   'supportsDynamicLoad': 'YES',
#   'url': 'https://plugins.jenkins.io/workflow-aggregator',
#   'version': 2.6},
#  {'active': True,
#   'backupVersion': None,
#   'bundled': False,
#   'deleted': False,
#   'dependencies': [{'optional': False,
#                     'shortName': 'workflow-step-api',
#                     'version': '2.16'},
#                    {'optional': False,
#                     'shortName': 'scm-api',
#                     'version': '2.2.6'},
#                    {'optional': False,
#                     'shortName': 'structs',
#                     'version': '1.17'},
#                    {'optional': True,
#                     'shortName': 'trilead-api',
#                     'version': '1.0.4'}],
#   'detached': False,
#   'downgradable': False,
#   'enabled': True,
#   'hasUpdate': False,
#   'longName': 'Pipeline: API',
#   'minimumJavaVersion': '1.8',
#   'pinned': False,
#   'requiredCoreVersion': '2.150.3',
#   'shortName': 'workflow-api',
#   'supportsDynamicLoad': 'MAYBE',
#   'url': 'https://plugins.jenkins.io/workflow-api',
#   'version': 2.40},
#  {'active': True,
#   'backupVersion': None,
#   'bundled': False,
#   'deleted': False,
#   'dependencies': [{'optional': False,
#                     'shortName': 'workflow-api',
#                     'version': '2.40'},
#                    {'optional': False,
#                     'shortName': 'workflow-durable-task-step',
#                     'version': '2.31'},
#                    {'optional': False,
#                     'shortName': 'workflow-step-api',
#                     'version': '2.22'},
#                    {'optional': False,
#                     'shortName': 'apache-httpcomponents-client-4-api',
#                     'version': '4.5.10-2.0'},
#                    {'optional': False,
#                     'shortName': 'mailer',
#                     'version': '1.32'},
#                    {'optional': False,
#                     'shortName': 'structs',
#                     'version': '1.20'},
#                    {'optional': True,
#                     'shortName': 'trilead-api',
#                     'version': '1.0.4'}],
#   'detached': False,
#   'downgradable': False,
#   'enabled': True,
#   'hasUpdate': False,
#   'longName': 'Pipeline: Basic Steps',
#   'minimumJavaVersion': '1.8',
#   'pinned': False,
#   'requiredCoreVersion': '2.164.3',
#   'shortName': 'workflow-basic-steps',
#   'supportsDynamicLoad': 'MAYBE',
#   'url': 'https://plugins.jenkins.io/workflow-basic-steps',
#   'version': 2.20},
#  {'active': True,
#   'backupVersion': None,
#   'bundled': False,
#   'deleted': False,
#   'dependencies': [{'optional': False,
#                     'shortName': 'workflow-api',
#                     'version': '2.33'},
#                    {'optional': False,
#                     'shortName': 'workflow-cps',
#                     'version': '2.71'},
#                    {'optional': False,
#                     'shortName': 'workflow-scm-step',
#                     'version': '2.7'},
#                    {'optional': False,
#                     'shortName': 'workflow-step-api',
#                     'version': '2.20'},
#                    {'optional': False,
#                     'shortName': 'workflow-support',
#                     'version': '3.3'},
#                    {'optional': False,
#                     'shortName': 'cloudbees-folder',
#                     'version': '6.1.2'},
#                    {'optional': False,
#                     'shortName': 'credentials',
#                     'version': '2.1.18'},
#                    {'optional': False,
#                     'shortName': 'git-server',
#                     'version': '1.7'},
#                    {'optional': False,
#                     'shortName': 'scm-api',
#                     'version': '2.6.3'},
#                    {'optional': False,
#                     'shortName': 'script-security',
#                     'version': '1.70'},
#                    {'optional': False,
#                     'shortName': 'structs',
#                     'version': '1.19'},
#                    {'optional': True,
#                     'shortName': 'trilead-api',
#                     'version': '1.0.4'}],
#   'detached': False,
#   'downgradable': False,
#   'enabled': True,
#   'hasUpdate': False,
#   'longName': 'Pipeline: Shared Groovy Libraries',
#   'minimumJavaVersion': '1.8',
#   'pinned': False,
#   'requiredCoreVersion': '2.138.4',
#   'shortName': 'workflow-cps-global-lib',
#   'supportsDynamicLoad': 'MAYBE',
#   'url': 'https://plugins.jenkins.io/workflow-cps-global-lib',
#   'version': 2.16},
#  {'active': True,
#   'backupVersion': None,
#   'bundled': False,
#   'deleted': False,
#   'dependencies': [{'optional': False,
#                     'shortName': 'workflow-api',
#                     'version': '2.40'},
#                    {'optional': False,
#                     'shortName': 'workflow-scm-step',
#                     'version': '2.9'},
#                    {'optional': False,
#                     'shortName': 'workflow-step-api',
#                     'version': '2.22'},
#                    {'optional': False,
#                     'shortName': 'workflow-support',
#                     'version': '3.4'},
#                    {'optional': False,
#                     'shortName': 'scm-api',
#                     'version': '2.6.3'},
#                    {'optional': False,
#                     'shortName': 'script-security',
#                     'version': '1.71'},
#                    {'optional': False,
#                     'shortName': 'structs',
#                     'version': '1.20'},
#                    {'optional': False,
#                     'shortName': 'ace-editor',
#                     'version': '1.1'},
#                    {'optional': False,
#                     'shortName': 'jquery-detached',
#                     'version': '1.2.1'},
#                    {'optional': True,
#                     'shortName': 'trilead-api',
#                     'version': '1.0.4'}],
#   'detached': False,
#   'downgradable': False,
#   'enabled': True,
#   'hasUpdate': False,
#   'longName': 'Pipeline: Groovy',
#   'minimumJavaVersion': '1.8',
#   'pinned': False,
#   'requiredCoreVersion': '2.176.4',
#   'shortName': 'workflow-cps',
#   'supportsDynamicLoad': 'MAYBE',
#   'url': 'https://plugins.jenkins.io/workflow-cps',
#   'version': 2.81},
#  {'active': True,
#   'backupVersion': None,
#   'bundled': False,
#   'deleted': False,
#   'dependencies': [{'optional': False,
#                     'shortName': 'workflow-api',
#                     'version': '2.33'},
#                    {'optional': False,
#                     'shortName': 'workflow-step-api',
#                     'version': '2.20'},
#                    {'optional': False,
#                     'shortName': 'workflow-support',
#                     'version': '3.3'},
#                    {'optional': False,
#                     'shortName': 'durable-task',
#                     'version': '1.33'},
#                    {'optional': False,
#                     'shortName': 'scm-api',
#                     'version': '2.2.6'},
#                    {'optional': False,
#                     'shortName': 'script-security',
#                     'version': '1.58'},
#                    {'optional': False,
#                     'shortName': 'structs',
#                     'version': '1.18'},
#                    {'optional': True,
#                     'shortName': 'trilead-api',
#                     'version': '1.0.4'}],
#   'detached': False,
#   'downgradable': False,
#   'enabled': True,
#   'hasUpdate': False,
#   'longName': 'Pipeline: Nodes and Processes',
#   'minimumJavaVersion': '1.8',
#   'pinned': False,
#   'requiredCoreVersion': '2.176.1',
#   'shortName': 'workflow-durable-task-step',
#   'supportsDynamicLoad': 'MAYBE',
#   'url': 'https://plugins.jenkins.io/workflow-durable-task-step',
#   'version': 2.35},
#  {'active': True,
#   'backupVersion': None,
#   'bundled': False,
#   'deleted': False,
#   'dependencies': [{'optional': False,
#                     'shortName': 'workflow-api',
#                     'version': '2.36'},
#                    {'optional': False,
#                     'shortName': 'workflow-step-api',
#                     'version': '2.20'},
#                    {'optional': False,
#                     'shortName': 'workflow-support',
#                     'version': '3.3'},
#                    {'optional': True,
#                     'shortName': 'trilead-api',
#                     'version': '1.0.4'}],
#   'detached': False,
#   'downgradable': False,
#   'enabled': True,
#   'hasUpdate': False,
#   'longName': 'Pipeline: Job',
#   'minimumJavaVersion': '1.8',
#   'pinned': False,
#   'requiredCoreVersion': '2.138.4',
#   'shortName': 'workflow-job',
#   'supportsDynamicLoad': 'MAYBE',
#   'url': 'https://plugins.jenkins.io/workflow-job',
#   'version': 2.39},
#  {'active': True,
#   'backupVersion': None,
#   'bundled': False,
#   'deleted': False,
#   'dependencies': [{'optional': False,
#                     'shortName': 'workflow-api',
#                     'version': '2.27'},
#                    {'optional': False,
#                     'shortName': 'workflow-cps',
#                     'version': '2.53'},
#                    {'optional': False,
#                     'shortName': 'workflow-job',
#                     'version': '2.21'},
#                    {'optional': False,
#                     'shortName': 'workflow-scm-step',
#                     'version': '2.4'},
#                    {'optional': False,
#                     'shortName': 'workflow-step-api',
#                     'version': '2.13'},
#                    {'optional': False,
#                     'shortName': 'workflow-support',
#                     'version': '2.17'},
#                    {'optional': False,
#                     'shortName': 'branch-api',
#                     'version': '2.0.21'},
#                    {'optional': False,
#                     'shortName': 'cloudbees-folder',
#                     'version': '6.1.2'},
#                    {'optional': False,
#                     'shortName': 'scm-api',
#                     'version': '2.2.7'},
#                    {'optional': False,
#                     'shortName': 'script-security',
#                     'version': '1.42'},
#                    {'optional': False,
#                     'shortName': 'structs',
#                     'version': '1.17'},
#                    {'optional': True,
#                     'shortName': 'trilead-api',
#                     'version': '1.0.4'}],
#   'detached': False,
#   'downgradable': False,
#   'enabled': True,
#   'hasUpdate': False,
#   'longName': 'Pipeline: Multibranch',
#   'minimumJavaVersion': None,
#   'pinned': False,
#   'requiredCoreVersion': '2.121.1',
#   'shortName': 'workflow-multibranch',
#   'supportsDynamicLoad': 'MAYBE',
#   'url': 'https://plugins.jenkins.io/workflow-multibranch',
#   'version': 2.21},
#  {'active': True,
#   'backupVersion': None,
#   'bundled': False,
#   'deleted': False,
#   'dependencies': [{'optional': False,
#                     'shortName': 'workflow-step-api',
#                     'version': '2.9'},
#                    {'optional': True,
#                     'shortName': 'command-launcher',
#                     'version': '1.0'},
#                    {'optional': True,
#                     'shortName': 'jdk-tool',
#                     'version': '1.0'},
#                    {'optional': True,
#                     'shortName': 'trilead-api',
#                     'version': '1.0.4'}],
#   'detached': False,
#   'downgradable': False,
#   'enabled': True,
#   'hasUpdate': False,
#   'longName': 'Pipeline: SCM Step',
#   'minimumJavaVersion': '1.8',
#   'pinned': False,
#   'requiredCoreVersion': '2.60',
#   'shortName': 'workflow-scm-step',
#   'supportsDynamicLoad': 'MAYBE',
#   'url': 'https://plugins.jenkins.io/workflow-scm-step',
#   'version': 2.11},
#  {'active': True,
#   'backupVersion': None,
#   'bundled': False,
#   'deleted': False,
#   'dependencies': [{'optional': False,
#                     'shortName': 'structs',
#                     'version': '1.20'},
#                    {'optional': True,
#                     'shortName': 'trilead-api',
#                     'version': '1.0.4'}],
#   'detached': False,
#   'downgradable': False,
#   'enabled': True,
#   'hasUpdate': False,
#   'longName': 'Pipeline: Step API',
#   'minimumJavaVersion': '1.8',
#   'pinned': False,
#   'requiredCoreVersion': '2.138.4',
#   'shortName': 'workflow-step-api',
#   'supportsDynamicLoad': 'YES',
#   'url': 'https://plugins.jenkins.io/workflow-step-api',
#   'version': 2.22},
#  {'active': True,
#   'backupVersion': None,
#   'bundled': False,
#   'deleted': False,
#   'dependencies': [{'optional': False,
#                     'shortName': 'workflow-api',
#                     'version': '2.40'},
#                    {'optional': False,
#                     'shortName': 'workflow-step-api',
#                     'version': '2.22'},
#                    {'optional': False,
#                     'shortName': 'scm-api',
#                     'version': '2.6.3'},
#                    {'optional': False,
#                     'shortName': 'script-security',
#                     'version': '1.71'},
#                    {'optional': True,
#                     'shortName': 'trilead-api',
#                     'version': '1.0.4'}],
#   'detached': False,
#   'downgradable': False,
#   'enabled': True,
#   'hasUpdate': False,
#   'longName': 'Pipeline: Supporting APIs',
#   'minimumJavaVersion': '1.8',
#   'pinned': False,
#   'requiredCoreVersion': '2.176.4',
#   'shortName': 'workflow-support',
#   'supportsDynamicLoad': 'MAYBE',
#   'url': 'https://plugins.jenkins.io/workflow-support',
#   'version': 3.5}]
